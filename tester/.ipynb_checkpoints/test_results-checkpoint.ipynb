# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

import platform
import os
import multiprocessing
import datetime

# %matplotlib inline

# %%
# consts
# number of iterations:
config = open("tester_config", "r")
times = int(config.readline()[6:-1])

# %% [markdown]
# # Tester results.
# ### Current system:

# %%
print "Version:", platform.platform()
print "CPU cores:", multiprocessing.cpu_count()
print "Page size:", os.sysconf('SC_PAGE_SIZE')
print "Current time:", datetime.datetime.now()
# Out:
# Version: Darwin-14.5.0-x86_64-i386-64bit
# CPU cores: 8
# Page size: 4096
# Current time: 2016-05-03 16:42:06.174716

# %%
data = pd.read_csv("test_result.txt", sep=' ', header=None, names=["lib", 'test', 'test_name'] + [i for i in range(times)])

# %%
values = [i for i in range(times)]
data["mean"] = data[values].mean(axis=1)
data["std"]  = data[values].std(axis=1)
data["testid"] = data["test"] + "_" + data["test_name"]
data = data.reindex_axis(sorted(data.columns), axis=1)
tests = sorted(list(set(data['testid'].tolist())))
libs = sorted(list(set(data['lib'].tolist())))

# %%
# data

# %% [markdown]
# ## Rankings
# * **1 point ** for being in std of the best test performer,
# * **0.25 point** for being in each quartile,
# * **-1** for failed test,
# * **-0.5** for timeout,
#
# **BONUS**:
# * **0.5** for best std in each test
# * **1** for full test passage

# %%
ranks = pd.DataFrame(index=libs, columns=tests).fillna(-1)
ranks['All test passed'] = np.zeros(len(libs))

datarank = data[['lib', 'testid', 'mean', 'std']]
for test in tests:
    testf = datarank[datarank.testid == test]
    best_mean = testf['mean'][testf['mean'] != -1].min()
    best_mean_std = testf[testf['mean'] == best_mean]["std"].values[0]
    
    best_std = testf['std'][testf['std'] != 0].min()
    
    quantile1 = testf['mean'].quantile(0.25)
    quantile2 = testf['mean'].quantile(0.5)
    quantile3 = testf['mean'].quantile(0.75)
    
    for index, row in testf.iterrows():
        # quartille
        if row["mean"] != -1:        
            if (np.abs(row["mean"] - best_mean) <= np.abs(row['std'] + best_mean_std)):
                ranks.set_value(row['lib'], row['testid'], 1)
            elif row["mean"] < quantile1:
                ranks.set_value(row['lib'], row['testid'], 0.75)
            elif row["mean"] < quantile2:
                ranks.set_value(row['lib'], row['testid'], 0.5)
            elif row["mean"] < quantile3:
                ranks.set_value(row['lib'], row['testid'], 0.25)
            else:
                ranks.set_value(row['lib'], row['testid'], 0.0)
        else:
            ranks.set_value(row['lib'], row['testid'], -0.5)
            
        # best std:
        if row["std"] == best_std:
            ranks.loc[row['lib'], row['testid']] += 0.5
            
all_passed = ranks[ranks < 0].any(axis=1)

for i, item in all_passed.iteritems():
    if item == False: 
        ranks.set_value(i, 'All test passed', 1)

# %%
colors = ["pale red", "pale red", "pale red", "pale red", "amber", "amber"]
cmap = matplotlib.colors.ListedColormap(sns.xkcd_palette(colors) + sns.light_palette("green", n_colors=10))

sns.set(font_scale=2)
sns.set_style("whitegrid")
plt.figure(figsize=(20,10))
sns.plt.title("Points for tests", fontsize=60)
sns.heatmap(ranks, annot=True, cmap=cmap, center=0, linewidths=.5)
plt.show()

# %%
## Code to shift "Test passage" plot to left
from IPython.display import HTML
HTML("""<script>
  $(document).ready(function(){
    $('div.prompt').hide();
    $('nav#menubar').hide();
  });
</script>
""")
# Out:
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('nav#menubar').hide();
#   });
# </script>

# %%
ranks["sum"] = ranks.sum(axis=1)

# for index, row in ranks.iterrows():
#     for test in tests:
#         if row[test] < 0:
#             ranks.set_value(row[test], 'BONUS', 0)

ranks.sort_values(by=['sum'], ascending=False, inplace=True)
# ranks

# %%
plt.figure(figsize=(25, 10))
sns.set(font_scale=2)
sns.plt.title("Final ranks", fontsize=50, y=1.03)
sns.barplot(y=ranks["sum"], x=ranks.index)
plt.ylabel('Points')
plt.show()

# %% [markdown]
# ## Results by each test.
# There are only libs that passed the test.

# %%
# data without timeout values.
passed_data = data[data["mean"] != -1]

# %%
val = passed_data.set_index(passed_data["testid"]).drop(["test", "test_name", "mean", "std", 'testid'], axis=1)
sns.set(font_scale=2)
for test in tests:
    plt.figure(figsize=(25, 8))
    sns.plt.title(test, fontsize=30, y=1.03)
    a = val[val.index == test]
    a = a.set_index(a['lib']).drop(["lib"], axis=1).transpose()
    ax = sns.boxplot(data=a)
    sns.swarmplot(data=a, size=5, ax=ax, color="black")
    plt.ylabel('Time')
    plt.show()

# %% [markdown]
# ## Raw results
# with mean and std

# %%
pd.set_option('display.max_rows', len(data))
data.drop(values, axis=1)
# Out:
#               lib      mean       std          test         test_name  \
# 0         aivanov  0.190153  0.003239       aivanov             test1
# 1         aivanov  0.585489  0.002126       aivanov             test2
# 2         aivanov  0.001640  0.000091      aneganov         test_func
# 3         aivanov  0.001817  0.000063      dkopyrin           test_ht
# 4         aivanov  0.068213  0.001531      dkopyrin       test_ladder
# 5         aivanov -1.000000  0.000000      dkopyrin      test_pyramid
# 6         aivanov -1.000000  0.000000      dkopyrin  test_pyramid_vac
# 7         aivanov  0.001688  0.000072      dkopyrin       test_simple
# 8         aivanov  0.001571  0.000035      dkopyrin   test_simple_map
# 9         aivanov  4.757941  1.213217      dkopyrin       test_stairs
# 10        aivanov  5.246206  1.509568      dkopyrin   test_stairs_vac
# 11        aivanov  1.354184  0.047400    dokhlopkov  test_performance
# 12        aivanov  0.001713  0.000080    dokhlopkov       test_simple
# 13        aivanov  0.130483  0.001998    enikitenko      performance1
# 14        aivanov  0.041973  0.002626    enikitenko      performance2
# 15        aivanov  0.019400  0.004328  kshcherbatov            psycho
# 16        aivanov  0.001710  0.000073       osamara              test
# 17       aneganov  0.193935  0.002887       aivanov             test1
# 18       aneganov  1.068556  0.004992       aivanov             test2
# 19       aneganov  0.002040  0.000093      aneganov         test_func
# 20       aneganov  0.021166  0.000212      apotapov              test
# 21       aneganov  0.002392  0.000080      dkopyrin           test_ht
# 22       aneganov  0.033845  0.000517      dkopyrin       test_ladder
# 23       aneganov  1.634670  0.022812      dkopyrin      test_pyramid
# 24       aneganov  1.648826  0.082725      dkopyrin  test_pyramid_vac
# 25       aneganov  0.002006  0.000076      dkopyrin       test_simple
# 26       aneganov  0.001949  0.000070      dkopyrin   test_simple_map
# 27       aneganov  0.536010  0.003406      dkopyrin       test_stairs
# 28       aneganov  0.534092  0.019803      dkopyrin   test_stairs_vac
# 29       aneganov  1.467044  0.013026    dokhlopkov  test_performance
# 30       aneganov  0.002830  0.000117    dokhlopkov       test_simple
# 31       aneganov  1.804518  0.011137    enikitenko      performance1
# 32       aneganov  0.094488  0.000610    enikitenko      performance2
# 33       aneganov  0.025745  0.000924  kshcherbatov            psycho
# 34       aneganov  0.002037  0.000076       osamara              test
# 35       apotapov  0.001876  0.000107      aneganov         test_func
# 36       apotapov  0.031433  0.000313      apotapov              test
# 37       apotapov  0.012073  0.000182      dkopyrin           test_ht
# 38       apotapov -1.000000  0.000000      dkopyrin      test_pyramid
# 39       apotapov -1.000000  0.000000      dkopyrin  test_pyramid_vac
# 40       apotapov  0.001920  0.000179      dkopyrin       test_simple
# 41       apotapov  0.001750  0.000062      dkopyrin   test_simple_map
# 42       apotapov -1.000000  0.000000      dkopyrin       test_stairs
# 43       apotapov -1.000000  0.000000      dkopyrin   test_stairs_vac
# 44       apotapov -1.000000  0.000000    dokhlopkov  test_performance
# 45       apotapov  0.002333  0.000085    dokhlopkov       test_simple
# 46       apotapov -1.000000  0.000000    enikitenko      performance1
# 47       apotapov  1.717097  0.182894    enikitenko      performance2
# 48       apotapov  0.063231  0.005269  kshcherbatov            psycho
# 49       apotapov  0.001885  0.000072       osamara              test
# 50       dkopyrin  0.189073  0.003296       aivanov             test1
# 51       dkopyrin  0.273827  0.000974       aivanov             test2
# 52       dkopyrin  0.001644  0.000067      aneganov         test_func
# 53       dkopyrin  0.001825  0.000053      apotapov              test
# 54       dkopyrin  0.001649  0.000072      dkopyrin           test_ht
# 55       dkopyrin  0.042516  0.000529      dkopyrin       test_ladder
# 56       dkopyrin  0.138557  0.001017      dkopyrin      test_pyramid
# 57       dkopyrin  0.269774  0.010051      dkopyrin  test_pyramid_vac
# 58       dkopyrin  0.001640  0.000074      dkopyrin       test_simple
# 59       dkopyrin  0.001637  0.000062      dkopyrin   test_simple_map
# 60       dkopyrin  0.107318  0.013152      dkopyrin       test_stairs
# 61       dkopyrin  0.083941  0.000891      dkopyrin   test_stairs_vac
# 62       dkopyrin  1.295067  0.018941    dokhlopkov  test_performance
# 63       dkopyrin  0.001675  0.000089    dokhlopkov       test_simple
# 64       dkopyrin  0.036684  0.000307    enikitenko      performance1
# 65       dkopyrin  0.006155  0.000191    enikitenko      performance2
# 66       dkopyrin  0.002069  0.000109  kshcherbatov            psycho
# 67       dkopyrin  0.001669  0.000088       osamara              test
# 68     dokhlopkov  0.001723  0.000060       aivanov             test2
# 69     dokhlopkov  0.001644  0.000154      aneganov         test_func
# 70     dokhlopkov  0.017046  0.000178      apotapov              test
# 71     dokhlopkov  0.040312  0.003083      dkopyrin           test_ht
# 72     dokhlopkov  0.327262  0.004466      dkopyrin       test_ladder
# 73     dokhlopkov -1.000000  0.000000      dkopyrin  test_pyramid_vac
# 74     dokhlopkov  0.001653  0.000087      dkopyrin       test_simple
# 75     dokhlopkov  0.001592  0.000061      dkopyrin   test_simple_map
# 76     dokhlopkov  1.319355  0.003688    dokhlopkov  test_performance
# 77     dokhlopkov  0.001638  0.000063    dokhlopkov       test_simple
# 78     dokhlopkov  1.185562  0.046629    enikitenko      performance1
# 79     dokhlopkov  0.001704  0.000060       osamara              test
# 80     enikitenko  0.190720  0.003365       aivanov             test1
# 81     enikitenko  0.272127  0.000604       aivanov             test2
# 82     enikitenko  0.001682  0.000094      aneganov         test_func
# 83     enikitenko  0.002139  0.000051      apotapov              test
# 84     enikitenko  0.001714  0.000066      dkopyrin           test_ht
# 85     enikitenko  0.056922  0.001007      dkopyrin       test_ladder
# 86     enikitenko  0.150600  0.001931      dkopyrin      test_pyramid
# 87     enikitenko -1.000000  0.000000      dkopyrin  test_pyramid_vac
# 88     enikitenko  0.001718  0.000095      dkopyrin       test_simple
# 89     enikitenko  0.001660  0.000073      dkopyrin   test_simple_map
# 90     enikitenko  0.072264  0.000381      dkopyrin       test_stairs
# 91     enikitenko  4.919906  1.773116      dkopyrin   test_stairs_vac
# 92     enikitenko  1.281837  0.002879    dokhlopkov  test_performance
# 93     enikitenko  0.001899  0.000068    dokhlopkov       test_simple
# 94     enikitenko  0.035125  0.000220    enikitenko      performance1
# 95     enikitenko  0.006504  0.000175    enikitenko      performance2
# 96     enikitenko  0.002146  0.000092  kshcherbatov            psycho
# 97     enikitenko  0.001797  0.000072       osamara              test
# 98   kshcherbatov  0.190597  0.000983       aivanov             test1
# 99   kshcherbatov  0.543062  0.000894       aivanov             test2
# 100  kshcherbatov  0.001695  0.000088      aneganov         test_func
# 101  kshcherbatov  0.002234  0.000073      apotapov              test
# 102  kshcherbatov  0.002500  0.000073      dkopyrin           test_ht
# 103  kshcherbatov  0.047571  0.000405      dkopyrin       test_ladder
# 104  kshcherbatov  0.717253  0.007193      dkopyrin      test_pyramid
# 105  kshcherbatov  1.019762  0.139768      dkopyrin  test_pyramid_vac
# 106  kshcherbatov  0.001694  0.000060      dkopyrin       test_simple
# 107  kshcherbatov  0.001692  0.000063      dkopyrin   test_simple_map
# 108  kshcherbatov  0.243170  0.001064      dkopyrin       test_stairs
# 109  kshcherbatov  0.332349  0.047096      dkopyrin   test_stairs_vac
# 110  kshcherbatov  1.294746  0.029261    dokhlopkov  test_performance
# 111  kshcherbatov  0.001952  0.000078    dokhlopkov       test_simple
# 112  kshcherbatov  0.031610  0.000273    enikitenko      performance1
# 113  kshcherbatov  0.021752  0.000301    enikitenko      performance2
# 114  kshcherbatov  0.013074  0.000278  kshcherbatov            psycho
# 115  kshcherbatov  0.001824  0.000145       osamara              test
# 116       osamara  0.001614  0.000080      aneganov         test_func
# 117       osamara  0.001663  0.000072      dkopyrin       test_simple
# 118       osamara  0.001590  0.000056      dkopyrin   test_simple_map
# 119       osamara  0.001644  0.000084    dokhlopkov       test_simple
# 120       osamara  0.710483  0.019471    enikitenko      performance1
# 121       osamara  0.001671  0.000067       osamara              test
#
#                           testid
# 0                  aivanov_test1
# 1                  aivanov_test2
# 2             aneganov_test_func
# 3               dkopyrin_test_ht
# 4           dkopyrin_test_ladder
# 5          dkopyrin_test_pyramid
# 6      dkopyrin_test_pyramid_vac
# 7           dkopyrin_test_simple
# 8       dkopyrin_test_simple_map
# 9           dkopyrin_test_stairs
# 10      dkopyrin_test_stairs_vac
# 11   dokhlopkov_test_performance
# 12        dokhlopkov_test_simple
# 13       enikitenko_performance1
# 14       enikitenko_performance2
# 15           kshcherbatov_psycho
# 16                  osamara_test
# 17                 aivanov_test1
# 18                 aivanov_test2
# 19            aneganov_test_func
# 20                 apotapov_test
# 21              dkopyrin_test_ht
# 22          dkopyrin_test_ladder
# 23         dkopyrin_test_pyramid
# 24     dkopyrin_test_pyramid_vac
# 25          dkopyrin_test_simple
# 26      dkopyrin_test_simple_map
# 27          dkopyrin_test_stairs
# 28      dkopyrin_test_stairs_vac
# 29   dokhlopkov_test_performance
# 30        dokhlopkov_test_simple
# 31       enikitenko_performance1
# 32       enikitenko_performance2
# 33           kshcherbatov_psycho
# 34                  osamara_test
# 35            aneganov_test_func
# 36                 apotapov_test
# 37              dkopyrin_test_ht
# 38         dkopyrin_test_pyramid
# 39     dkopyrin_test_pyramid_vac
# 40          dkopyrin_test_simple
# 41      dkopyrin_test_simple_map
# 42          dkopyrin_test_stairs
# 43      dkopyrin_test_stairs_vac
# 44   dokhlopkov_test_performance
# 45        dokhlopkov_test_simple
# 46       enikitenko_performance1
# 47       enikitenko_performance2
# 48           kshcherbatov_psycho
# 49                  osamara_test
# 50                 aivanov_test1
# 51                 aivanov_test2
# 52            aneganov_test_func
# 53                 apotapov_test
# 54              dkopyrin_test_ht
# 55          dkopyrin_test_ladder
# 56         dkopyrin_test_pyramid
# 57     dkopyrin_test_pyramid_vac
# 58          dkopyrin_test_simple
# 59      dkopyrin_test_simple_map
# 60          dkopyrin_test_stairs
# 61      dkopyrin_test_stairs_vac
# 62   dokhlopkov_test_performance
# 63        dokhlopkov_test_simple
# 64       enikitenko_performance1
# 65       enikitenko_performance2
# 66           kshcherbatov_psycho
# 67                  osamara_test
# 68                 aivanov_test2
# 69            aneganov_test_func
# 70                 apotapov_test
# 71              dkopyrin_test_ht
# 72          dkopyrin_test_ladder
# 73     dkopyrin_test_pyramid_vac
# 74          dkopyrin_test_simple
# 75      dkopyrin_test_simple_map
# 76   dokhlopkov_test_performance
# 77        dokhlopkov_test_simple
# 78       enikitenko_performance1
# 79                  osamara_test
# 80                 aivanov_test1
# 81                 aivanov_test2
# 82            aneganov_test_func
# 83                 apotapov_test
# 84              dkopyrin_test_ht
# 85          dkopyrin_test_ladder
# 86         dkopyrin_test_pyramid
# 87     dkopyrin_test_pyramid_vac
# 88          dkopyrin_test_simple
# 89      dkopyrin_test_simple_map
# 90          dkopyrin_test_stairs
# 91      dkopyrin_test_stairs_vac
# 92   dokhlopkov_test_performance
# 93        dokhlopkov_test_simple
# 94       enikitenko_performance1
# 95       enikitenko_performance2
# 96           kshcherbatov_psycho
# 97                  osamara_test
# 98                 aivanov_test1
# 99                 aivanov_test2
# 100           aneganov_test_func
# 101                apotapov_test
# 102             dkopyrin_test_ht
# 103         dkopyrin_test_ladder
# 104        dkopyrin_test_pyramid
# 105    dkopyrin_test_pyramid_vac
# 106         dkopyrin_test_simple
# 107     dkopyrin_test_simple_map
# 108         dkopyrin_test_stairs
# 109     dkopyrin_test_stairs_vac
# 110  dokhlopkov_test_performance
# 111       dokhlopkov_test_simple
# 112      enikitenko_performance1
# 113      enikitenko_performance2
# 114          kshcherbatov_psycho
# 115                 osamara_test
# 116           aneganov_test_func
# 117         dkopyrin_test_simple
# 118     dkopyrin_test_simple_map
# 119       dokhlopkov_test_simple
# 120      enikitenko_performance1
# 121                 osamara_test

# %%
from IPython.display import HTML
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

<footer id="attribution" style="float:right; color:#999; background:#fff;">
Created with Jupyter by dokhlopkov.
</footer>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
#
# <footer id="attribution" style="float:right; color:#999; background:#fff;">
# Created with Jupyter by dokhlopkov.
# </footer>
